# %% [markdown]
# # Reading the Data

# %%
import pandas as pd

#bucket='credit-card-clients'
#data_key = 'default of credit card clients.xls'
#data_location = 's3://{}/{}'.format(bucket, data_key)

file_name = 'default of credit card clients.xls'
data_set = pd.read_excel(file_name)
data_set
# Out:
#       Unnamed: 0         X1      X2           X3        X4   X5     X6     X7  \
# 0             ID  LIMIT_BAL     SEX    EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2
# 1              1      20000  female   university   married   24      2      2
# 2              2     120000  female   university    single   26     -1      2
# 3              3      90000  female   university    single   34      0      0
# 4              4      50000  female   university   married   37      0      0
# ...          ...        ...     ...          ...       ...  ...    ...    ...
# 29996      29996     220000    male  high school   married   39      0      0
# 29997      29997     150000    male  high school    single   43     -1     -1
# 29998      29998      30000    male   university    single   37      4      3
# 29999      29999      80000    male  high school   married   41      1     -1
# 30000      30000      50000    male   university   married   46      0      0
#
# ...

# %% [markdown]
# I need to drop the first raw and the ID coulmn. Then I will reindex the DataFrame

# %%
data_set = data_set.drop(0)
data_set = data_set.drop(['Unnamed: 0'], axis = 1)
data_set.index -=1
data_set
# Out:
#            X1      X2           X3       X4  X5  X6  X7  X8  X9 X10  ...  \
# 0       20000  female   university  married  24   2   2  -1  -1  -2  ...
# 1      120000  female   university   single  26  -1   2   0   0   0  ...
# 2       90000  female   university   single  34   0   0   0   0   0  ...
# 3       50000  female   university  married  37   0   0   0   0   0  ...
# 4       50000    male   university  married  57  -1   0  -1   0   0  ...
# ...       ...     ...          ...      ...  ..  ..  ..  ..  ..  ..  ...
# 29995  220000    male  high school  married  39   0   0   0   0   0  ...
# 29996  150000    male  high school   single  43  -1  -1  -1  -1   0  ...
# 29997   30000    male   university   single  37   4   3   2  -1   0  ...
# 29998   80000    male  high school  married  41   1  -1   0   0   0  ...
# 29999   50000    male   university  married  46   0   0   0   0   0  ...
#
#          X15    X16    X17    X18    X19    X20   X21    X22   X23  Y
# ...

# %% [markdown]
# Using the info() function, I noticed that I need to cast the datatypes.

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      30000 non-null  object
#  1   X2      30000 non-null  object
#  2   X3      29669 non-null  object
#  3   X4      29677 non-null  object
#  4   X5      30000 non-null  object
#  5   X6      30000 non-null  object
#  6   X7      30000 non-null  object
#  7   X8      30000 non-null  object
#  8   X9      30000 non-null  object
#  9   X10     30000 non-null  object
#  10  X11     30000 non-null  object
#  11  X12     30000 non-null  object
#  12  X13     30000 non-null  object
#  13  X14     30000 non-null  object
#  14  X15     30000 non-null  object
#  15  X16     30000 non-null  object
#  16  X17     30000 non-null  object
#  17  X18     30000 non-null  object
#  18  X19     30000 non-null  object
#  19  X20     30000 non-null  object
#  20  X21     30000 non-null  object
# ...

# %%
data_set.convert_dtypes().dtypes
# Out:
# X1      Int64
# X2     string
# X3     object
# X4     object
# X5      Int64
# X6      Int64
# X7      Int64
# X8      Int64
# X9      Int64
# X10     Int64
# X11     Int64
# X12     Int64
# X13     Int64
# X14     Int64
# X15     Int64
# X16     Int64
# X17     Int64
# X18     Int64
# X19     Int64
# X20     Int64
# X21     Int64
# X22     Int64
# X23     Int64
# Y       Int64
# dtype: object

# %%
data_set = data_set.astype({'X1':'Int64','X2':'str','X3':'object','X4':'object',
                           'X5':'Int64','X6':'Int64','X7':'Int64','X8':'Int64',
                           'X9':'Int64','X10':'Int64', 'X11':'Int64', 'X12':'Int64',
                           'X13':'Int64', 'X14':'Int64', 'X15':'Int64', 'X16':'Int64',
                           'X17':'Int64', 'X18':'Int64', 'X19':'Int64', 'X20':'Int64',
                           'X21':'Int64', 'X22':'Int64', 'X23':'Int64','Y':'str'})

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      30000 non-null  Int64
#  1   X2      30000 non-null  object
#  2   X3      29669 non-null  object
#  3   X4      29677 non-null  object
#  4   X5      30000 non-null  Int64
#  5   X6      30000 non-null  Int64
#  6   X7      30000 non-null  Int64
#  7   X8      30000 non-null  Int64
#  8   X9      30000 non-null  Int64
#  9   X10     30000 non-null  Int64
#  10  X11     30000 non-null  Int64
#  11  X12     30000 non-null  Int64
#  12  X13     30000 non-null  Int64
#  13  X14     30000 non-null  Int64
#  14  X15     30000 non-null  Int64
#  15  X16     30000 non-null  Int64
#  16  X17     30000 non-null  Int64
#  17  X18     30000 non-null  Int64
#  18  X19     30000 non-null  Int64
#  19  X20     30000 non-null  Int64
#  20  X21     30000 non-null  Int64
# ...

# %%
data_set.describe()
# Out:
#                    X1            X5            X6            X7            X8  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667     35.518833     -0.016700     -0.133767     -0.166200
# std     129747.661567      9.528019      1.123802      1.197186      1.196868
# min      10000.000000     21.000000     -2.000000     -2.000000     -2.000000
# 25%      50000.000000     28.000000     -1.000000     -1.000000     -1.000000
# 50%     140000.000000     34.000000      0.000000      0.000000      0.000000
# 75%     240000.000000     41.000000      0.000000      0.000000      0.000000
# max    1000000.000000    267.000000      8.000000      8.000000      8.000000
#
#                  X9           X10           X11            X12            X13  \
# count  30000.000000  30000.000000  30000.000000   30000.000000   30000.000000
# mean      -0.220667     -0.266200     -0.291100   51223.330900   49179.075167
# ...

# %%
data_set.head()
# Out:
#        X1      X2          X3       X4  X5  X6  X7  X8  X9  X10  ...    X15  \
# 0   20000  female  university  married  24   2   2  -1  -1   -2  ...      0
# 1  120000  female  university   single  26  -1   2   0   0    0  ...   3272
# 2   90000  female  university   single  34   0   0   0   0    0  ...  14331
# 3   50000  female  university  married  37   0   0   0   0    0  ...  28314
# 4   50000    male  university  married  57  -1   0  -1   0    0  ...  20940
#
#      X16    X17   X18    X19    X20   X21   X22   X23  Y
# 0      0      0     0    689      0     0     0     0  1
# 1   3455   3261     0   1000   1000  1000     0  2000  1
# 2  14948  15549  1518   1500   1000  1000  1000  5000  0
# 3  28959  29547  2000   2019   1200  1100  1069  1000  0
# 4  19146  19131  2000  36681  10000  9000   689   679  0
#
# [5 rows x 24 columns]

# %% [markdown]
# # Exploring the Data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for column in data_set.select_dtypes(include=['object']).columns:
    display(pd.crosstab(index=data_set[column],
                        columns='% observations', 
                        normalize='columns'))
    print("# of unique values {}".format(data_set[column].nunique()))

# show summary statistics
display(data_set.describe())

# build histograms for each numeric feature
# %matplotlib inline
hist = data_set.hist(bins=30, sharey=True, figsize=(10, 10))
# Out:
# col_0   % observations
# X2
# female        0.603733
# male          0.396267
# # of unique values 2
# col_0            % observations
# X3
# 0                      0.000472
# graduate school        0.356770
# high school            0.165695
# others                 0.004179
# university             0.472884
# # of unique values 5
# col_0    % observations
# X4
# 0              0.001820
# married        0.460255
# single         0.537925
# # of unique values 3
# col_0  % observations
# Y
# 0              0.7788
# 1              0.2212
# # of unique values 2
#                    X1            X5            X6            X7            X8  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667     35.518833     -0.016700     -0.133767     -0.166200
# std     129747.661567      9.528019      1.123802      1.197186      1.196868
# min      10000.000000     21.000000     -2.000000     -2.000000     -2.000000
# ...

# %%
import seaborn as sns

f, ax = plt.subplots(figsize=(32, 26))
corr = data_set.corr()
mp = sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax, annot = True)
mp.set_title(label='dataset correlation', fontsize=20)
# Out:
# Text(0.5, 1.0, 'dataset correlation')

# %% [markdown]
# # Feature selection and Feature Engineering

# %%
model_data = pd.get_dummies(data_set)

# %% [markdown]
# I dropped some labels to avoid the dummy variable trap.

# %%
model_data = model_data.drop(['Y_0', 'X2_female', 'X3_0', 'X3_others', 'X4_0','X4_married', 'X3_high school'], axis = 1)

# %% [markdown]
# # Splitting the dataset

# %%
X = model_data.iloc[:, :-1].values
Y = model_data.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Training the model

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[4594  109]
#  [ 986  311]]

# %%
from sklearn.metrics import precision_score, recall_score

print('Precisions:', precision_score(y_test, y_pred))
print('Recall:', recall_score(y_test, y_pred))


from sklearn.metrics import f1_score

print('f1 score:', f1_score(y_test, y_pred))
# Out:
# Precisions: 0.7404761904761905
# Recall: 0.23978411719352352
# f1 score: 0.3622597553873035
